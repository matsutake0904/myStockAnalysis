# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
reader['investment_id'] in after_list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6b73ebfefbfe> in <module>
# ----> 1 reader['investment_id'] in after_list
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
path = '/Users/ryo/Work/python_work/kaggle/ubiquant_market/train.csv'
reader = pd.read_csv(path)

# %%
# 間引き処理（時系列を保存し、investment_idで間引き）

investment_id_list = reader['investment_id'].loc[~reader['investment_id'].duplicated()]
num =100
after_df = reader.loc[reader['investment_id'] % num == 0]
path_w = f'/Users/ryo/Work/python_work/kaggle/ubiquant_market/train_mabiki{num}.csv'
after_df.to_csv(path_w)
# Out:
#             row_id  time_id  investment_id    target       f_0       f_1  \
# 59           0_100        0            100 -0.354124 -1.024037 -1.016361
# 115          0_200        0            200  1.093119 -0.059321 -0.137431
# 174          0_300        0            300 -0.473633  0.293443 -1.895290
# 232          0_400        0            400  2.834663  0.717209 -0.514115
# 361          0_600        0            600 -0.175670 -1.377448 -0.388554
# ...            ...      ...            ...       ...       ...       ...
# 3140881  1219_3200     1219           3200 -0.003660  0.978113  0.060157
# 3140975  1219_3300     1219           3300 -0.395252  1.022938 -0.850347
# 3141066  1219_3400     1219           3400  3.444112  0.600402 -0.850347
# 3141157  1219_3500     1219           3500  0.877116  0.801554 -0.720275
# 3141251  1219_3600     1219           3600 -0.206597  0.605761 -1.370635
#
#               f_2       f_3       f_4       f_5  ...     f_290     f_291  \
# ...

# %%
reader2 = pd.read_csv(path_w)
reader2
# Out:
#        Unnamed: 0     row_id  time_id  investment_id    target       f_0  \
# 0              59      0_100        0            100 -0.354124 -1.024037
# 1             115      0_200        0            200  1.093119 -0.059321
# 2             174      0_300        0            300 -0.473633  0.293443
# 3             232      0_400        0            400  2.834663  0.717209
# 4             361      0_600        0            600 -0.175670 -1.377448
# ...           ...        ...      ...            ...       ...       ...
# 32563     3140881  1219_3200     1219           3200 -0.003660  0.978113
# 32564     3140975  1219_3300     1219           3300 -0.395252  1.022938
# 32565     3141066  1219_3400     1219           3400  3.444112  0.600402
# 32566     3141157  1219_3500     1219           3500  0.877116  0.801554
# 32567     3141251  1219_3600     1219           3600 -0.206597  0.605761
#
#             f_1       f_2       f_3       f_4  ...     f_290     f_291  \
# ...

# %%
# ヘッダーデータの抽出
header_data = reader[['row_id','time_id', 'investment_id', 'target', 'f_0','f_100','f_200','f_299']]
header_data
# Out:
#             row_id  time_id  investment_id    target       f_0     f_100  \
# 0              0_1        0              1 -0.300875  0.932573  0.666485
# 1              0_2        0              2 -0.231040  0.810802 -0.918706
# 2              0_6        0              6  0.568807  0.393974  1.038671
# 3              0_7        0              7 -1.064780 -2.343535 -0.918706
# 4              0_8        0              8 -0.531940  0.842057 -0.918706
# ...            ...      ...            ...       ...       ...       ...
# 3141405  1219_3768     1219           3768  0.033600  0.093530 -0.524826
# 3141406  1219_3769     1219           3769 -0.223264 -1.344935 -0.524826
# 3141407  1219_3770     1219           3770 -0.559415  0.979489 -0.524826
# 3141408  1219_3772     1219           3772  0.009599 -2.565332 -0.524826
# 3141409  1219_3773     1219           3773  1.212112 -0.089557  0.605587
#
#             f_200     f_299
# 0        0.000000  0.321566
# 1        0.000000 -0.343624
# ...

# %%
header_data.describe()
# Out:
#             time_id  investment_id        target           f_0         f_100  \
# count  3.141410e+06   3.141410e+06  3.141410e+06  3.141410e+06  3.141410e+06
# mean   6.654862e+02   1.885265e+03 -2.109231e-02  1.637029e-03 -1.286107e-02
# std    3.560434e+02   1.083616e+03  9.197057e-01  1.081097e+00  1.080358e+00
# min    0.000000e+00   0.000000e+00 -9.419646e+00 -1.765789e+01 -6.504582e+00
# 25%    3.530000e+02   9.520000e+02 -5.004572e-01 -4.071441e-01 -6.951518e-01
# 50%    7.040000e+02   1.882000e+03 -9.717009e-02  2.431158e-01 -2.627427e-01
# 75%    9.750000e+02   2.830000e+03  3.572908e-01  6.649507e-01  5.854224e-01
# max    1.219000e+03   3.773000e+03  1.203861e+01  7.845261e+00  1.730830e+01
#
#               f_200         f_299
# count  3.141410e+06  3.141410e+06
# mean  -3.660498e-02 -4.319445e-03
# std    7.932771e-01  1.010046e+00
# min   -1.174026e+01 -1.028264e+01
# 25%   -4.322745e-01 -5.080143e-01
# 50%    0.000000e+00 -2.824031e-01
# ...

# %%
data_01 = reader.loc[reader['investment_id']==1]

# %%
# data_01[['f_0']].diff()
data_01[data_01.columns[data_01.columns != 'row_id']].diff()
# Out:
#          time_id  investment_id    target       f_0       f_1       f_2  \
# 0            NaN            NaN       NaN       NaN       NaN       NaN
# 2272         1.0            0.0 -0.616170 -0.558998  0.182657  0.421308
# 4547         1.0            0.0  0.436812 -1.208270  0.008884  0.038513
# 6822         1.0            0.0  0.156671  1.185896 -0.081310  0.122930
# 9107         1.0            0.0  2.818041  0.173765 -0.147319 -0.282988
# ...          ...            ...       ...       ...       ...       ...
# 3124271      1.0            0.0  0.245601 -0.102415 -0.188218 -0.095267
# 3127703      1.0            0.0 -0.368451 -0.060263 -0.235197 -0.508735
# 3131121      1.0            0.0  0.192977 -0.579139 -0.384444  0.003089
# 3134541      1.0            0.0  0.016841 -0.208266 -0.019068 -0.056107
# 3137973      1.0            0.0  0.737128  0.188032 -0.212037 -0.011402
#
#               f_3       f_4       f_5       f_6  ...     f_290     f_291  \
# ...

# %%
time_max = 50
tmp = data_01.loc[data_01['time_id'] < time_max]
fig, ax = plt.subplots()
ax.plot(tmp['time_id'], tmp['f_0'], label = 'f_0')
ax.plot(tmp['time_id'], tmp['f_50'], label = 'f_50')
ax.plot(tmp['time_id'], tmp['f_100'], label = 'f_100')
ax.plot(tmp['time_id'], tmp['f_200'], label = 'f_200')
ax.plot(tmp['time_id'], tmp['f_250'], label = 'f_250')
ax.plot(tmp['time_id'], tmp['target'], label = 'target')
ax.legend()
plt.show()

# %%
time_max = 50
tmp = header_data.loc[header_data['time_id'] < time_max, heade]
sns.pairplot(header_data)

# %%
data_01.

# %%
aa.append(data_01)

# %%
aa
# Out:
# [         row_id  time_id  investment_id    target       f_0       f_1  \
#  0           0_1        0              1 -0.300875  0.932573  0.113691
#  2272        1_1        1              1 -0.917045  0.373575  0.296349
#  4547        2_1        2              1 -0.480234 -0.834696  0.305233
#  6822        3_1        3              1 -0.323562  0.351200  0.223923
#  9107        4_1        4              1  2.494479  0.524965  0.076604
#  ...         ...      ...            ...       ...       ...       ...
#  3124271  1215_1     1215              1  0.078338  0.517945 -0.259744
#  3127703  1216_1     1216              1 -0.290113  0.457682 -0.494941
#  3131121  1217_1     1217              1 -0.097136 -0.121456 -0.879386
#  3134541  1218_1     1218              1 -0.080295 -0.329723 -0.898453
#  3137973  1219_1     1219              1  0.656833 -0.141690 -1.110491
#
#                f_2       f_3       f_4       f_5  ...     f_290     f_291  \
# ...

# %%
#重複行を削除して出力
data_01['investment_id'].drop_duplicates()
# Out:
# 0    1
# Name: investment_id, dtype: int64

# %%
path2 = '/Users/ryo/Work/python_work/kaggle/ubiquant_market/train_head1000.csv'
data_02 = pd.read_csv(path2)
list(data_02['investment_id'].loc[~data_02['investment_id'].duplicated()])
# Out:
# [1,
#  2,
#  6,
#  7,
#  8,
#  9,
#  10,
#  12,
#  13,
#  14,
#  16,
#  17,
#  19,
#  20,
#  22,
#  24,
#  29,
#  30,
#  31,
#  32,
#  33,
#  34,
#  35,
#  36,
#  40,
#  41,
#  42,
#  44,
#  45,
#  46,
#  47,
#  48,
#  50,
#  51,
#  54,
#  55,
#  58,
#  59,
#  61,
#  62,
#  63,
#  66,
#  67,
#  73,
#  74,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  82,
#  84,
#  87,
#  89,
#  92,
#  95,
#  98,
#  99,
#  100,
#  101,
#  102,
#  107,
#  109,
#  110,
#  114,
#  115,
#  117,
#  120,
#  121,
#  125,
#  128,
#  129,
#  130,
#  131,
#  132,
#  134,
#  135,
#  137,
#  139,
#  141,
#  142,
#  143,
#  145,
#  147,
#  149,
#  152,
#  155,
#  156,
#  159,
#  160,
#  161,
#  162,
#  164,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  174,
#  179,
#  182,
#  184,
#  185,
#  187,
#  188,
#  191,
#  193,
#  194,
#  195,
#  196,
#  197,
#  199,
#  200,
#  202,
#  205,
#  206,
#  207,
#  208,
#  209,
#  211,
#  213,
#  214,
#  216,
#  217,
#  218,
#  219,
#  220,
#  222,
#  225,
#  226,
# ...

# %%
for i in range(300):
    ind = 'f_' + str(i)
    after_ind = 'diff_f_' + str(i)
    data_01[after_ind]=data_01[data_01.columns[data_01.columns != 'row_id']].diff()[ind]
# Out:
# <ipython-input-60-79f95cf98552>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_01[after_ind]=data_01[data_01.columns[data_01.columns != 'row_id']].diff()[ind]

# %%
data_01
# Out:
#          row_id  time_id  investment_id    target       f_0       f_1  \
# 0           0_1        0              1 -0.300875  0.932573  0.113691
# 2272        1_1        1              1 -0.917045  0.373575  0.296349
# 4547        2_1        2              1 -0.480234 -0.834696  0.305233
# 6822        3_1        3              1 -0.323562  0.351200  0.223923
# 9107        4_1        4              1  2.494479  0.524965  0.076604
# ...         ...      ...            ...       ...       ...       ...
# 3124271  1215_1     1215              1  0.078338  0.517945 -0.259744
# 3127703  1216_1     1216              1 -0.290113  0.457682 -0.494941
# 3131121  1217_1     1217              1 -0.097136 -0.121456 -0.879386
# 3134541  1218_1     1218              1 -0.080295 -0.329723 -0.898453
# 3137973  1219_1     1219              1  0.656833 -0.141690 -1.110491
#
#               f_2       f_3       f_4       f_5  ...  diff_f_290  diff_f_291  \
# ...

# %%
data_03 = data_01

# %%
for i in range(300):
    ind = 'f_' + str(i)
    after_ind = 'diff_f_' + str(i)
    data_03[after_ind] = pd.Series()
# Out:
# <ipython-input-63-997b4f864aad>:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   data_03[after_ind] = pd.Series()
# <ipython-input-63-997b4f864aad>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_03[after_ind] = pd.Series()

# %%
data_tmp = data_01.head(100)
for i in range(300):
    ind = 'f_' + str(i)
    after_ind = 'diff_f_' + str(i)
    data_03.loc[data_03['row_id'] == data_tmp['row_id']][after_ind] = data_tmp[data_tmp.columns[data_tmp.columns != 'row_id']].diff()[ind]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-b13dfe8d210c> in <module>
#       3     ind = 'f_' + str(i)
#       4     after_ind = 'diff_f_' + str(i)
# ----> 5     data_03.loc[data_03['row_id'] == data_tmp['row_id']][after_ind] = data_tmp[data_tmp.columns[data_tmp.columns != 'row_id']].diff()[ind]
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     363
#     364         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 365             raise ValueError("Can only compare identically-labeled Series objects")
#     366
# ...

# %%
data_03['row_id'] == data_01['row_id']
# Out:
# 0          True
# 2272       True
# 4547       True
# 6822       True
# 9107       True
#            ...
# 3124271    True
# 3127703    True
# 3131121    True
# 3134541    True
# 3137973    True
# Name: row_id, Length: 1108, dtype: bool

# %%
header_data
# Out:
#             row_id  time_id  investment_id    target       f_0     f_100  \
# 0              0_1        0              1 -0.300875  0.932573  0.666485
# 1              0_2        0              2 -0.231040  0.810802 -0.918706
# 2              0_6        0              6  0.568807  0.393974  1.038671
# 3              0_7        0              7 -1.064780 -2.343535 -0.918706
# 4              0_8        0              8 -0.531940  0.842057 -0.918706
# ...            ...      ...            ...       ...       ...       ...
# 3141405  1219_3768     1219           3768  0.033600  0.093530 -0.524826
# 3141406  1219_3769     1219           3769 -0.223264 -1.344935 -0.524826
# 3141407  1219_3770     1219           3770 -0.559415  0.979489 -0.524826
# 3141408  1219_3772     1219           3772  0.009599 -2.565332 -0.524826
# 3141409  1219_3773     1219           3773  1.212112 -0.089557  0.605587
#
#             f_200     f_299
# 0        0.000000  0.321566
# 1        0.000000 -0.343624
# ...

# %%
h_list = [0,100,200,299]
    # 追加カラムの初期化
header_2 = header_data
for i in h_list:
    after_ind = 'diff_f_' + str(i)
    header_data[after_ind] = pd.Series()
# Out:
# <ipython-input-73-c2caf186658c>:6: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   header_data[after_ind] = pd.Series()
# <ipython-input-73-c2caf186658c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   header_data[after_ind] = pd.Series()

# %%
investment_id_list = list(header_data['investment_id'].loc[~header_data['investment_id'].duplicated()])

for inv_id in investment_id_list:
    ins_list = header_data['investment_id'] == inv_id
    print(True in list(ins_list))
    for i in h_list:
        ind = 'f_' + str(i)
        after_ind = 'diff_f_' + str(i)
        header_data.loc[ins_list, after_ind] = header_data[header_data.columns[header_data.columns != 'row_id']].loc[ins_list].diff()[ind]
# Out:
#   File "<ipython-input-160-b16478b2ef00>", line 10
#     header_data.loc[ins_list, after_ind].isna() = 0
#     ^
# SyntaxError: cannot assign to function call

# %%
 for i in h_list:
        ind = 'f_' + str(i)
        after_ind = 'diff_f_' + str(i)
        header_data.loc[header_data[after_ind].isna(), after_ind] = 0

# %%
ind='f_0'
after_ind = 'diff_f_0'
header_data.loc[ins_list, after_ind] = header_data[header_data.columns[header_data.columns != 'row_id']].loc[ins_list].diff()[ind]
# Out:
# /Users/ryo/miniforge3/lib/python3.9/site-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
header_data
# Out:
#             row_id  time_id  investment_id    target       f_0     f_100  \
# 0              0_1        0              1 -0.300875  0.932573  0.666485
# 1              0_2        0              2 -0.231040  0.810802 -0.918706
# 2              0_6        0              6  0.568807  0.393974  1.038671
# 3              0_7        0              7 -1.064780 -2.343535 -0.918706
# 4              0_8        0              8 -0.531940  0.842057 -0.918706
# ...            ...      ...            ...       ...       ...       ...
# 3141405  1219_3768     1219           3768  0.033600  0.093530 -0.524826
# 3141406  1219_3769     1219           3769 -0.223264 -1.344935 -0.524826
# 3141407  1219_3770     1219           3770 -0.559415  0.979489 -0.524826
# 3141408  1219_3772     1219           3772  0.009599 -2.565332 -0.524826
# 3141409  1219_3773     1219           3773  1.212112 -0.089557  0.605587
#
#             f_200     f_299  diff_f_0  diff_f_100    diff_f_200  diff_f_299
# ...

# %%
#DO ALL

# path = '/Users/ryo/Work/python_work/kaggle/ubiquant_market/train.csv'
# reader_data = pd.read_csv(path)
h_list = [i for i in range(300)]

investment_id_list = list(reader_data['investment_id'].loc[~reader_data['investment_id'].duplicated()])

for inv_id in investment_id_list:
    ins_list = reader_data['investment_id'] == inv_id
    print(True in list(ins_list))
    for i in h_list:
        ind = 'f_' + str(i)
        after_ind = 'diff_f_' + str(i)
        reader_data.loc[ins_list, after_ind] = reader_data[reader_data.columns[reader_data.columns != 'row_id']].loc[ins_list].diff()[ind]
for i in h_list:
    ind = 'f_' + str(i)
    after_ind = 'diff_f_' + str(i)
    reader_data.loc[reader_data[after_ind].isna(), after_ind] = 0
    
# df = reader_data
# from sklearn.model_selection import train_test_split
# import lightgbm as lgb
# from lightgbm import *

# features = [f'f_{i}' for i in h_list]
# for i in h_list:
#     features.append(f'diff_f_{i}') 
# target = 'target'
# df_features = df[features]

# X_train, X, Y_train, Y = train_test_split(df_features, df[target], train_size=0.6, shuffle=False)
# X_val, X_test, Y_val, Y_test = train_test_split(X, Y, train_size=0.5, shuffle=False)

# import warnings
# import lightgbm as lgb
# from scipy.stats import pearsonr

# warnings.filterwarnings('ignore')

# lgb_train = lgb.Dataset(X_train, Y_train)
# lgb_eval = lgb.Dataset(X_val, Y_val, reference=lgb_train)

# params = {'seed': 1,
#            'objective': "regression",
#            'learning_rate': 0.02,
#            'bagging_fraction': 0.2,
#            'bagging_freq': 1,
#            'feature_fraction': 0.3,
#            'max_depth': 5,
#            'min_child_samples': 50,
#            'num_leaves': 64}

# gbm = lgb.train(params,
#                 lgb_train,
#                 num_boost_round=19450815,
#                 valid_sets=lgb_eval,
#                 #verbose_eval=False,
#                 early_stopping_rounds=10,
#                 )
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.datasets import load_iris
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report

# #特徴量の重要度
# feature = gbm.feature_importance(importance_type='gain')

# #特徴量の重要度を上から順に出力する
# f = pd.DataFrame({'number': range(0, len(feature)),
#              'feature': feature[:]})
# f2 = f.sort_values('feature',ascending=False)

# #特徴量の名前
# label = X_train.columns[0:]

# #特徴量の重要度順（降順）
# indices = np.argsort(feature)[::-1]

# for i in range(len(feature)):
#     print(str(i + 1) + "   " + str(label[indices[i]]) + "   " + str(feature[indices[i]]))

# plt.title('Feature Importance')
# plt.bar(range(len(feature)),feature[indices], color='lightblue', align='center')
# plt.xticks(range(len(feature)), label[indices], rotation = 90)
# plt.xlim([-1, len(feature)])
# plt.tight_layout()
# plt.show()
# Out:
# True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ec207be86ea5> in <module>
#      13         ind = 'f_' + str(i)
#      14         after_ind = 'diff_f_' + str(i)
# ---> 15         reader_data.loc[ins_list, after_ind] = reader_data[reader_data.columns[reader_data.columns != 'row_id']].loc[ins_list].diff()[ind]
#      16 for i in h_list:
#      17     ind = 'f_' + str(i)
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2916             indexer = np.where(indexer)[0]
#    2917
# -> 2918         data = self._take_with_is_copy(indexer, axis=1)
#    2919
#    2920         if is_single_key:
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3361         See the docstring of `take` for full explanation of the parameters.
#    3362         """
# ...

# %%
df = reader_data
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from lightgbm import *

features = [f'f_{i}' for i in h_list]
for i in h_list:
    features.append(f'diff_f_{i}') 
target = 'target'
df_features = df[features]

X_train, X, Y_train, Y = train_test_split(df_features, df[target], train_size=0.6, shuffle=False)
X_val, X_test, Y_val, Y_test = train_test_split(X, Y, train_size=0.5, shuffle=False)

# %%
import warnings
import lightgbm as lgb
from scipy.stats import pearsonr

warnings.filterwarnings('ignore')

lgb_train = lgb.Dataset(X_train, Y_train)
lgb_eval = lgb.Dataset(X_val, Y_val, reference=lgb_train)

params = {'seed': 1,
           'objective': "regression",
           'learning_rate': 0.02,
           'bagging_fraction': 0.2,
           'bagging_freq': 1,
           'feature_fraction': 0.3,
           'max_depth': 5,
           'min_child_samples': 50,
           'num_leaves': 64}

gbm = lgb.train(params,
                lgb_train,
                num_boost_round=19450815,
                valid_sets=lgb_eval,
                #verbose_eval=False,
                early_stopping_rounds=10,
                )

# %%
Y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)

score_tuple = pearsonr(Y_test, Y_pred)
score = score_tuple[0]
print(f"Validation Pearsonr score : {score:.4f}")
# Out:
# Validation Pearsonr score : 0.0360

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

#特徴量の重要度
feature = gbm.feature_importance(importance_type='gain')

#特徴量の重要度を上から順に出力する
f = pd.DataFrame({'number': range(0, len(feature)),
             'feature': feature[:]})
f2 = f.sort_values('feature',ascending=False)

#特徴量の名前
label = X_train.columns[0:]

#特徴量の重要度順（降順）
indices = np.argsort(feature)[::-1]

for i in range(len(feature)):
    print(str(i + 1) + "   " + str(label[indices[i]]) + "   " + str(feature[indices[i]]))

plt.title('Feature Importance')
plt.bar(range(len(feature)),feature[indices], color='lightblue', align='center')
plt.xticks(range(len(feature)), label[indices], rotation = 90)
plt.xlim([-1, len(feature)])
plt.tight_layout()
plt.show()
# Out:
# 1   f_100   15342.526390463114
# 2   f_200   11160.22023126483
# 3   diff_f_200   8936.259850372327
# 4   diff_f_100   8769.75440660026
# 5   diff_f_0   7982.695684501901
# 6   f_0   7936.501025386519
# 7   f_299   4880.939407401718
# 8   diff_f_299   3143.5373557212297

# %%
for i in h_list:
    features.append(f'diff_f_{i}')

# %%
features
# Out:
# ['f_0',
#  'f_100',
#  'f_200',
#  'f_299',
#  'diff_f_0',
#  'diff_f_100',
#  'diff_f_200',
#  'diff_f_299']

# %%
 for i in h_list:
        ind = 'f_' + str(i)
        after_ind = 'diff_f_' + str(i)
        header_data.loc[header_data[after_ind].isna(), after_ind] = 0

# %%
header_data
# Out:
#             row_id  time_id  investment_id    target       f_0     f_100  \
# 0              0_1        0              1 -0.300875  0.932573  0.666485
# 1              0_2        0              2 -0.231040  0.810802 -0.918706
# 2              0_6        0              6  0.568807  0.393974  1.038671
# 3              0_7        0              7 -1.064780 -2.343535 -0.918706
# 4              0_8        0              8 -0.531940  0.842057 -0.918706
# ...            ...      ...            ...       ...       ...       ...
# 3141405  1219_3768     1219           3768  0.033600  0.093530 -0.524826
# 3141406  1219_3769     1219           3769 -0.223264 -1.344935 -0.524826
# 3141407  1219_3770     1219           3770 -0.559415  0.979489 -0.524826
# 3141408  1219_3772     1219           3772  0.009599 -2.565332 -0.524826
# 3141409  1219_3773     1219           3773  1.212112 -0.089557  0.605587
#
#             f_200     f_299  diff_f_0  diff_f_100    diff_f_200  diff_f_299
# ...

# %%
reader_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-12bccd1d7bcb> in <module>
# ----> 1 reader_data
#
# NameError: name 'reader_data' is not defined

# %%
レアで
