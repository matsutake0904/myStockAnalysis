# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from ubiquant_my_library import my_library

# %%
path = '/Users/ryo/Work/python_work/kaggle/ubiquant_market/train.csv'
reader = my_library.reduce_mem_usage(pd.read_csv(path))
# reader = pd.read_csv(path)
# Out:
# Memory usage of dataframe is 7285.99 MB
# Memory usage after optimization is: 1931.46 MB
# Decreased by 73.5%

# %%
#parquetファイル出力
# out_path = '/Users/ryo/Work/python_work/kaggle/ubiquant_market/train.parquet'
out_path = '/Users/ryo/Work/python_work/kaggle/ubiquant_market/train_low_memory.parquet'
reader.astype('float32').to_parquet(out_path)

# %%
del reader

# %%
out_path = '/Users/ryo/Work/python_work/kaggle/ubiquant_market/train_low_memory.parquet'
reader2 = pd.read_parquet(out_path)

# %%
reader2
# Out:
#              row_id  time_id  investment_id    target       f_0       f_1  \
# 0               1.0      0.0            1.0 -0.300781  0.932617  0.113708
# 1               2.0      0.0            2.0 -0.231079  0.811035 -0.514160
# 2               6.0      0.0            6.0  0.568848  0.394043  0.615723
# 3               7.0      0.0            7.0 -1.064453 -2.343750 -0.011871
# 4               8.0      0.0            8.0 -0.531738  0.842285 -0.262939
# ...             ...      ...            ...       ...       ...       ...
# 3141405  12193768.0   1219.0         3768.0  0.033600  0.093506 -0.720215
# 3141406  12193769.0   1219.0         3769.0 -0.223267 -1.344727 -0.199951
# 3141407  12193770.0   1219.0         3770.0 -0.559570  0.979492 -1.110352
# 3141408  12193772.0   1219.0         3772.0  0.009598 -2.564453  0.320312
# 3141409  12193773.0   1219.0         3773.0  1.211914 -0.089539  0.190186
#
#               f_2       f_3       f_4       f_5  ...     f_290     f_291  \
# 0       -0.402100  0.378418 -0.203979 -0.413574  ...  0.365967 -1.095703
# 1        0.742188 -0.616699 -0.194214  1.771484  ... -0.154175  0.912598
# 2        0.567871 -0.607910  0.068909 -1.083008  ... -0.138062  0.912598
# 3        1.875000 -0.606445 -0.586914 -0.815918  ...  0.382080  0.912598
# 4        2.330078 -0.583496 -0.618164 -0.742676  ... -0.170410  0.912598
# ...           ...       ...       ...       ...  ...       ...       ...
# 3141405 -0.345459 -0.438721 -0.166992 -0.437256  ... -0.285889 -1.232422
# 3141406 -0.107727 -0.454590 -0.221924 -0.141113  ...  0.184570 -1.232422
# 3141407  1.006836 -0.467285 -0.159546  1.355469  ... -0.756348 -1.232422
# 3141408  0.076599  1.379883 -0.155396 -0.688965  ... -0.756348 -1.232422
# 3141409 -0.548340  0.151245  0.079773  0.447998  ... -0.317139  0.811523
#
#             f_292     f_293     f_294     f_295     f_296     f_297     f_298  \
# 0        0.200073  0.819336  0.941406 -0.086792 -1.086914 -1.044922 -0.287598
# 1       -0.734375  0.819336  0.941406 -0.387695 -1.086914 -0.929688 -0.974121
# 2       -0.551758 -1.220703 -1.060547 -0.219116 -1.086914 -0.612305 -0.113953
# 3       -0.266357 -1.220703  0.941406 -0.608887  0.104919 -0.783203  1.151367
# 4       -0.741211 -1.220703  0.941406 -0.588379  0.104919  0.753418  1.345703
# ...           ...       ...       ...       ...       ...       ...       ...
# 3141405 -0.660645  0.875488  0.421631 -0.427979 -0.075562 -0.533203 -0.193726
# 3141406 -0.670410  0.875488  0.421631 -0.729980 -1.514648  0.013145 -0.890137
# 3141407  0.820801 -1.142578  0.421631 -0.363281  1.363281 -0.079102 -1.580078
# 3141408  0.133057 -1.142578  0.421631 -0.375244 -1.514648 -0.973633  0.608887
# 3141409  3.271484  0.875488  0.421631 -0.170654  1.363281 -0.563477  0.669434
#
#             f_299
# 0        0.321533
# 1       -0.343506
# 2        0.243652
# 3       -0.773438
# 4       -0.737793
# ...           ...
# 3141405 -0.581543
# 3141406 -0.589844
# 3141407 -0.297607
# 3141408 -0.372070
# 3141409  0.456299
#
# [3141410 rows x 304 columns]

# %%
reader2 = my_library.add_diff_average_columns(reader2)

# %%
out_path2 = '/Users/ryo/Work/python_work/kaggle/ubiquant_market/train_diffave.parquet'
reader2.to_parquet(out_path2)
